# %% [markdown]
# <a href="https://colab.research.google.com/github/DulaniDeSilva/NeuralNetworks_DeepLearning/blob/main/Neural_network_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: mount drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/CS409
# Out:
# /content/drive/MyDrive/CS409

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Data Preprocessing
# 1. Removing NaNs
# 2. Remove duplicates
# 3. Converting categorical to numerical conversion
# 4. Normalization
# 5.Outlier handing => histogram,

# %% [markdown]
# Reading the dataset

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/CS409/weatherAUS.csv')

# %%
df.head(10)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# 5  2008-12-06   Albury     14.6     29.7       0.2          NaN       NaN
# 6  2008-12-07   Albury     14.3     25.0       0.0          NaN       NaN
# 7  2008-12-08   Albury      7.7     26.7       0.0          NaN       NaN
# 8  2008-12-09   Albury      9.7     31.9       0.0          NaN       NaN
# 9  2008-12-10   Albury     13.1     30.1       1.4          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# ...

# %%
df.tail()
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 145455       NaN           E           31.0         SE  ...        51.0
# 145456       NaN         NNW           22.0         SE  ...        56.0
# 145457       NaN           N           37.0         SE  ...        53.0
# 145458       NaN          SE           28.0        SSE  ...        51.0
# 145459       NaN         NaN            NaN        ESE  ...        62.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# ...

# %% [markdown]
# # Characteristics of the dataset

# %%
df.shape
# Out:
# (145460, 23)

# %% [markdown]
# Summary of the daraset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %% [markdown]
# Describe statistical mettrics only for numerical columns

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %% [markdown]
# Decribe- summary of descriptive statistics for categorical column

# %%
df.describe(include = 'object')
# Out:
#               Date  Location WindGustDir WindDir9am WindDir3pm RainToday  \
# count       145460    145460      135134     134894     141232    142199
# unique        3436        49          16         16         16         2
# top     2013-11-12  Canberra           W          N         SE        No
# freq            49      3436        9915      11758      10838    110319
#
#        RainTomorrow
# count        142193
# unique            2
# top              No
# freq         110316

# %% [markdown]
# NAN values

# %%
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %% [markdown]
# duplicate records

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Start data preprocessing

# %% [markdown]
# Remove duplicates

# %%
df = df.drop_duplicates()

# %% [markdown]
# Handle missing values (NANS)

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56420 entries, 6049 to 142302
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           56420 non-null  object
#  1   Location       56420 non-null  object
#  2   MinTemp        56420 non-null  float64
#  3   MaxTemp        56420 non-null  float64
#  4   Rainfall       56420 non-null  float64
#  5   Evaporation    56420 non-null  float64
#  6   Sunshine       56420 non-null  float64
#  7   WindGustDir    56420 non-null  object
#  8   WindGustSpeed  56420 non-null  float64
#  9   WindDir9am     56420 non-null  object
#  10  WindDir3pm     56420 non-null  object
#  11  WindSpeed9am   56420 non-null  float64
#  12  WindSpeed3pm   56420 non-null  float64
#  13  Humidity9am    56420 non-null  float64
#  14  Humidity3pm    56420 non-null  float64
#  15  Pressure9am    56420 non-null  float64
#  16  Pressure3pm    56420 non-null  float64
# ...

# %%
df.head()
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 6049  2009-01-01    Cobar     17.9     35.2       0.0         12.0      12.3
# 6050  2009-01-02    Cobar     18.4     28.9       0.0         14.8      13.0
# 6052  2009-01-04    Cobar     19.4     37.6       0.0         10.8      10.6
# 6053  2009-01-05    Cobar     21.9     38.4       0.0         11.4      12.2
# 6054  2009-01-06    Cobar     24.2     41.0       0.0         11.2       8.4
#
#      WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 6049         SSW           48.0        ENE  ...        20.0         13.0
# 6050           S           37.0        SSE  ...        30.0          8.0
# 6052         NNE           46.0        NNE  ...        42.0         22.0
# 6053         WNW           31.0        WNW  ...        37.0         22.0
# 6054         WNW           35.0         NW  ...        19.0         15.0
#
# ...

# %% [markdown]
# reset to 0

# %%
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2009-01-01    Cobar     17.9     35.2       0.0         12.0      12.3
# 1  2009-01-02    Cobar     18.4     28.9       0.0         14.8      13.0
# 2  2009-01-04    Cobar     19.4     37.6       0.0         10.8      10.6
# 3  2009-01-05    Cobar     21.9     38.4       0.0         11.4      12.2
# 4  2009-01-06    Cobar     24.2     41.0       0.0         11.2       8.4
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0         SSW           48.0        ENE  ...        20.0         13.0
# 1           S           37.0        SSE  ...        30.0          8.0
# 2         NNE           46.0        NNE  ...        42.0         22.0
# 3         WNW           31.0        WNW  ...        37.0         22.0
# 4         WNW           35.0         NW  ...        19.0         15.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %% [markdown]
# Featurre engineering- seperate data records to day month year

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Day'] = df['Date'].dt.day
df['Month'] = df['Date'].dt.month
df['Year'] = df['Date'].dt.year

# %%
df.head()
# Out:
#         Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0 2009-01-01    Cobar     17.9     35.2       0.0         12.0      12.3
# 1 2009-01-02    Cobar     18.4     28.9       0.0         14.8      13.0
# 2 2009-01-04    Cobar     19.4     37.6       0.0         10.8      10.6
# 3 2009-01-05    Cobar     21.9     38.4       0.0         11.4      12.2
# 4 2009-01-06    Cobar     24.2     41.0       0.0         11.2       8.4
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Pressure3pm  Cloud9am  Cloud3pm  \
# 0         SSW           48.0        ENE  ...      1004.4       2.0       5.0
# 1           S           37.0        SSE  ...      1012.1       1.0       1.0
# 2         NNE           46.0        NNE  ...      1009.2       1.0       6.0
# 3         WNW           31.0        WNW  ...      1009.1       1.0       5.0
# 4         WNW           35.0         NW  ...      1007.4       1.0       6.0
#
#    Temp9am  Temp3pm  RainToday  RainTomorrow  Day  Month  Year
# ...

# %% [markdown]
# Convert categorical data nto numerical data

# %%
from sklearn.preprocessing import LabelEncoder

# %%
categorical_columns = df.select_dtypes(include=['object']).columns

# %%
print(categorical_columns)
# Out:
# Index(['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday',
#        'RainTomorrow'],
#       dtype='object')

# %%
label_encoder = LabelEncoder()

# %%
for column in categorical_columns:
    print(column)
    df[column] = label_encoder.fit_transform(df[column])
    print(label_encoder.classes_)
    print(df[column].unique())
    print()
# Out:
# Location
# ['AliceSprings' 'Brisbane' 'Cairns' 'Canberra' 'Cobar' 'CoffsHarbour'
#  'Darwin' 'Hobart' 'Melbourne' 'MelbourneAirport' 'Mildura' 'Moree'
#  'MountGambier' 'NorfolkIsland' 'Nuriootpa' 'Perth' 'PerthAirport'
#  'Portland' 'Sale' 'Sydney' 'SydneyAirport' 'Townsville' 'WaggaWagga'
#  'Watsonia' 'Williamtown' 'Woomera']
# [ 4  5 11 13 19 20 22 24  3 18  9  8 10 17 23  1  2 21 12 14 25 16 15  7
#   0  6]
#
# WindGustDir
# ['E' 'ENE' 'ESE' 'N' 'NE' 'NNE' 'NNW' 'NW' 'S' 'SE' 'SSE' 'SSW' 'SW' 'W'
#  'WNW' 'WSW']
# [11  8  5 14  3  9  1  4  0 12 13 15  6  2 10  7]
#
# WindDir9am
# ['E' 'ENE' 'ESE' 'N' 'NE' 'NNE' 'NNW' 'NW' 'S' 'SE' 'SSE' 'SSW' 'SW' 'W'
#  'WNW' 'WSW']
# [ 1 10  5 14  7  3  8  9  4 13 11  0  6  2 15 12]
#
# WindDir3pm
# ['E' 'ENE' 'ESE' 'N' 'NE' 'NNE' 'NNW' 'NW' 'S' 'SE' 'SSE' 'SSW' 'SW' 'W'
#  'WNW' 'WSW']
# [12 10  6 15 14  8  1  3  9  5  7  0  2  4 11 13]
#
# RainToday
# ['No' 'Yes']
# [0 1]
#
# RainTomorrow
# ['No' 'Yes']
# [0 1]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56420 entries, 0 to 56419
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           56420 non-null  datetime64[ns]
#  1   Location       56420 non-null  int64
#  2   MinTemp        56420 non-null  float64
#  3   MaxTemp        56420 non-null  float64
#  4   Rainfall       56420 non-null  float64
#  5   Evaporation    56420 non-null  float64
#  6   Sunshine       56420 non-null  float64
#  7   WindGustDir    56420 non-null  int64
#  8   WindGustSpeed  56420 non-null  float64
#  9   WindDir9am     56420 non-null  int64
#  10  WindDir3pm     56420 non-null  int64
#  11  WindSpeed9am   56420 non-null  float64
#  12  WindSpeed3pm   56420 non-null  float64
#  13  Humidity9am    56420 non-null  float64
#  14  Humidity3pm    56420 non-null  float64
#  15  Pressure9am    56420 non-null  float64
#  16  Pressure3pm    56420 non-null  float64
# ...

# %%
df.head()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0 2009-01-01         4     17.9     35.2       0.0         12.0      12.3
# 1 2009-01-02         4     18.4     28.9       0.0         14.8      13.0
# 2 2009-01-04         4     19.4     37.6       0.0         10.8      10.6
# 3 2009-01-05         4     21.9     38.4       0.0         11.4      12.2
# 4 2009-01-06         4     24.2     41.0       0.0         11.2       8.4
#
#    WindGustDir  WindGustSpeed  WindDir9am  ...  Pressure3pm  Cloud9am  \
# 0           11           48.0           1  ...       1004.4       2.0
# 1            8           37.0          10  ...       1012.1       1.0
# 2            5           46.0           5  ...       1009.2       1.0
# 3           14           31.0          14  ...       1009.1       1.0
# 4           14           35.0           7  ...       1007.4       1.0
#
#    Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  Day  Month  Year
# ...

# %% [markdown]
# Handling outliers

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Date             1544 days 00:00:00
# Location                       12.0
# MinTemp                         9.8
# MaxTemp                        11.0
# Rainfall                        0.6
# Evaporation                     4.6
# Sunshine                        5.7
# WindGustDir                     9.0
# WindGustSpeed                  17.0
# WindDir9am                      8.0
# WindDir3pm                      9.0
# WindSpeed9am                   11.0
# WindSpeed3pm                   13.0
# Humidity9am                    24.0
# Humidity3pm                    28.0
# Pressure9am                     9.1
# Pressure3pm                     9.3
# Cloud9am                        6.0
# Cloud3pm                        5.0
# Temp9am                        10.2
# Temp3pm                        10.5
# RainToday                       0.0
# RainTomorrow                    0.0
# Day                            15.0
# Month                           6.0
# Year                            4.0
# ...

# %%
outliers = (df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))
outliers_any = outliers.any(axis =1)

# %%
df_cleaned = df[~outliers_any]

# %%
df_cleaned.info()

# %% [markdown]
# dataset split

# %%
import splitfolders
input_folder = "/content/path"

# split the dataset into train and test
splitfolders.ratio(input_folder, output = "directory path",
                   seed = 42, ratio = (0.8, 0.2))

# %%
batch_size = 128
train_datagen = ImageDataGenerator(rescale = 1/255)
test_datagen = ImageDataGenerator(rescale = 1/255)

train_set = train_datagen.flow_from_directory(
    '/content/drive/MyDrive/CS409/train',
    target_size = (64, 64),
    batch_size = batch_size,
    class_mode = 'categorical'
)

test_set = test_datagen.flow_from_directory(
    '/content/drive/MyDrive/CS409/test',
    target_size = (64, 64),
    batch_size = batch_size,
    class_mode = 'categorical'
)
